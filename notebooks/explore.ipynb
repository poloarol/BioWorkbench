# %%
# %load_ext watermark
# %watermark -a "Paul A. Wambo" -v -p numpy,pandas,matplotlib,scipy,seaborn,sklearn,scanpy,squidpy

# %%
import scanpy as sc

# %%
adata = sc.datasets.pbmc3k()
adata

# %%
adata.shape

# %%
adata.X

# %%
adata.obs_names
